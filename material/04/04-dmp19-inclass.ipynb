# %% [markdown]
# *Praktische Dialogmodellierung, Universität Potsdam, SoSe 19, David Schlangen*
#
# # NLU mit RegExp, Vorüberlegungen

# %%
import pandas as pd
import json
import sys

from __future__ import division

from collections import Counter

import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# Den Pfad müssen Sie natürlich anpassen:

# %%
DSTC_path = '/Users/das/work/svn/Gits/t_Teaching/sose19-anw1-dialmod/material/DSTC'

# %%
sys.path.append(DSTC_path)
from _dstc2_scripts.dataset_walker import dataset_walker
from _dstc2_scripts import misc

# %%
dataset = dataset_walker("dstc2_dev", dataroot=DSTC_path + "/_Data/", labels=True)

# %% [markdown]
# ## Die unterliegende Ontologie

# %%
with open(DSTC_path + '/_dstc2_scripts/config/ontology_dstc2.json', 'r') as f:
    ontology = json.load(f)

# %%
ontology
# Out:
# {u'informable': {u'area': [u'centre', u'north', u'west', u'south', u'east'],
#   u'food': [u'afghan',
#    u'african',
#    u'afternoon tea',
#    u'asian oriental',
#    u'australasian',
#    u'australian',
#    u'austrian',
#    u'barbeque',
#    u'basque',
#    u'belgian',
#    u'bistro',
#    u'brazilian',
#    u'british',
#    u'canapes',
#    u'cantonese',
#    u'caribbean',
#    u'catalan',
#    u'chinese',
#    u'christmas',
#    u'corsica',
#    u'creative',
#    u'crossover',
#    u'cuban',
#    u'danish',
#    u'eastern european',
#    u'english',
#    u'eritrean',
#    u'european',
#    u'french',
#    u'fusion',
#    u'gastropub',
#    u'german',
#    u'greek',
#    u'halal',
#    u'hungarian',
#    u'indian',
#    u'indonesian',
#    u'international',
#    u'irish',
#    u'italian',
#    u'jamaican',
#    u'japanese',
#    u'korean',
#    u'kosher',
#    u'latin american',
#    u'lebanese',
#    u'light bites',
#    u'malaysian',
#    u'mediterranean',
#    u'mexican',
#    u'middle eastern',
#    u'modern american',
#    u'modern eclectic',
#    u'modern european',
#    u'modern global',
#    u'molecular gastronomy',
#    u'moroccan',
#    u'new zealand',
#    u'north african',
#    u'north american',
#    u'north indian',
#    u'northern european',
#    u'panasian',
#    u'persian',
#    u'polish',
#    u'polynesian',
#    u'portuguese',
#    u'romanian',
#    u'russian',
#    u'scandinavian',
#    u'scottish',
#    u'seafood',
#    u'singaporean',
#    u'south african',
#    u'south indian',
#    u'spanish',
#    u'sri lankan',
#    u'steakhouse',
#    u'swedish',
#    u'swiss',
#    u'thai',
#    u'the americas',
#    u'traditional',
#    u'turkish',
#    u'tuscan',
#    u'unusual',
#    u'vegetarian',
#    u'venetian',
#    u'vietnamese',
#    u'welsh',
#    u'world'],
#   u'name': [u'ali baba',
#    u'anatolia',
#    u'ask',
#    u'backstreet bistro',
#    u'bangkok city',
#    u'bedouin',
#    u'bloomsbury restaurant',
#    u'caffe uno',
#    u'cambridge lodge restaurant',
#    u'charlie chan',
#    u'chiquito restaurant bar',
#    u'city stop restaurant',
#    u'clowns cafe',
#    u'cocum',
#    u'cote',
#    u'cotto',
#    u'curry garden',
#    u'curry king',
#    u'curry prince',
#    u'curry queen',
#    u'da vinci pizzeria',
#    u'da vince pizzeria',
#    u'darrys cookhouse and wine shop',
#    u'de luca cucina and bar',
#    u'dojo noodle bar',
#    u'don pasquale pizzeria',
#    u'efes restaurant',
#    u'eraina',
#    u'fitzbillies restaurant',
#    u'frankie and bennys',
#    u'galleria',
#    u'golden house',
#    u'golden wok',
#    u'gourmet burger kitchen',
#    u'graffiti',
#    u'grafton hotel restaurant',
#    u'hakka',
#    u'hk fusion',
#    u'hotel du vin and bistro',
#    u'india house',
#    u'j restaurant',
#    u'jinling noodle bar',
#    u'kohinoor',
#    u'kymmoy',
#    u'la margherita',
#    u'la mimosa',
#    u'la raza',
#    u'la tasca',
#    u'lan hong house',
#    u'little seoul',
#    u'loch fyne',
#    u'mahal of cambridge',
#    u'maharajah tandoori restaurant',
#    u'meghna',
#    u'meze bar restaurant',
#    u'michaelhouse cafe',
#    u'midsummer house restaurant',
#    u'nandos',
#    u'nandos city centre',
#    u'panahar',
#    u'peking restaurant',
#    u'pipasha restaurant',
#    u'pizza express',
#    u'pizza express fen ditton',
#    u'pizza hut',
#    u'pizza hut city centre',
#    u'pizza hut cherry hinton',
#    u'pizza hut fen ditton',
#    u'prezzo',
#    u'rajmahal',
#    u'restaurant alimentum',
#    u'restaurant one seven',
#    u'restaurant two two',
#    u'rice boat',
#    u'rice house',
#    u'riverside brasserie',
#    u'royal spice',
#    u'royal standard',
#    u'saffron brasserie',
#    u'saigon city',
#    u'saint johns chop house',
#    u'sala thong',
#    u'sesame restaurant and bar',
#    u'shanghai family restaurant',
#    u'shiraz restaurant',
#    u'sitar tandoori',
#    u'stazione restaurant and coffee bar',
#    u'taj tandoori',
#    u'tandoori palace',
#    u'tang chinese',
#    u'thanh binh',
#    u'the cambridge chop house',
#    u'the copper kettle',
#    u'the cow pizza kitchen and bar',
#    u'the gandhi',
#    u'the gardenia',
#    u'the golden curry',
#    u'the good luck chinese food takeaway',
#    u'the hotpot',
#    u'the lucky star',
#    u'the missing sock',
#    u'the nirala',
#    u'the oak bistro',
#    u'the river bar steakhouse and grill',
#    u'the slug and lettuce',
#    u'the varsity restaurant',
#    u'travellers rest',
#    u'ugly duckling',
#    u'venue',
#    u'wagamama',
#    u'yippee noodle bar',
#    u'yu garden',
#    u'zizzi cambridge'],
#   u'pricerange': [u'cheap', u'moderate', u'expensive']},
#  u'method': [u'none',
#   u'byconstraints',
#   u'byname',
#   u'finished',
#   u'byalternatives'],
#  u'requestable': [u'addr',
#   u'area',
#   u'food',
#   u'phone',
#   u'pricerange',
#   u'postcode',
#   u'signature',
#   u'name']}

# %% [markdown]
# ## Als Hilfe beim Erstellen von Regeln

# %%
out = []
for m, call in enumerate(dataset):
    for n, (turn, label) in enumerate(call):
        this_turn = []
        usr_utt = label['transcription']
        usr_sem = label['semantics']['json']
        for full_da in usr_sem:
            # this is hard coding that there is only one slot/value pair in the list
            #  this seems to be the case in the data, but the format would allow
            #  for arbitrarily many. This conversion does not anymore do that.
            slot_vals = []
            for slot_value in full_da['slots']:
                slot_vals.extend([slot_value[0], slot_value[1]])
            out.append([m, n, usr_utt, full_da['act']] + slot_vals)

columns = 'dial_id turn_id usr_utt intent slot val'.split()
dstc_intent_df = pd.DataFrame(out, columns=columns)

# %%
dstc_intent_df.head(15)
# Out:
#     dial_id  turn_id  \
# 0   0        0
# 1   0        0
# 2   0        1
# 3   0        2
# 4   0        3
# 5   0        4
# 6   0        5
# 7   0        6
# 8   0        7
# 9   0        7
# 10  1        0
# 11  1        1
# 12  1        2
# 13  1        2
# 14  2        0
#
#                                                            usr_utt    intent  \
# 0   i would like to find an expensive restaurant in the south part  inform
# 1   i would like to find an expensive restaurant in the south part  inform
# 2   does not matter                                                 inform
# 3   any type of food is okay                                        inform
# 4   what is the address                                             request
# 5   what is the phone number                                        request
# 6   what type of food                                               request
# 7   okay thank                                                      thankyou
# 8   thank you good bye                                              thankyou
# 9   thank you good bye                                              bye
# 10  i want to find a cheap re                                       inform
# 11  i want to find the address                                      request
# 12  thank you good bye                                              thankyou
# 13  thank you good bye                                              bye
# 14  yes hi im looking for a restaurant in the north                 affirm
#
#           slot        val
# 0   pricerange  expensive
# 1   area        south
# 2   this        dontcare
# 3   food        dontcare
# 4   slot        addr
# 5   slot        phone
# 6   slot        food
# 7   None        None
# 8   None        None
# 9   None        None
# 10  pricerange  cheap
# 11  slot        addr
# 12  None        None
# 13  None        None
# 14  None        None

# %%
dstc_intent_df['intent'].unique()
# Out:
# array([u'inform', u'request', u'thankyou', u'bye', u'affirm', u'reqalts',
#        u'repeat', u'negate', u'confirm', u'hello', u'restart', u'deny',
#        u'reqmore'], dtype=object)

# %%
dstc_intent_df['intent'].value_counts()
# Out:
# inform      1942
# request     1165
# bye         526
# thankyou    510
# reqalts     275
# affirm      144
# negate      68
# confirm     39
# hello       18
# repeat      7
# deny        4
# restart     3
# reqmore     1
# Name: intent, dtype: int64

# %%
grouped = dstc_intent_df.groupby('intent')

# %%
grouped['slot'].value_counts()
# Out:
# intent   slot
# confirm  food          25
#          area          7
#          pricerange    7
# deny     food          4
# inform   food          838
#          area          454
#          pricerange    409
#          this          231
#          name          10
# request  slot          1165
# Name: slot, dtype: int64

# %%
dstc_intent_df[dstc_intent_df['intent'] == 'affirm'].sample(10)
# Out:
#       dial_id  turn_id          usr_utt  intent  slot   val
# 3931  422      0        yes              affirm  None  None
# 1206  136      6        yes              affirm  None  None
# 359   41       1        yes              affirm  None  None
# 2523  275      4        yes              affirm  None  None
# 2436  267      19       yes              affirm  None  None
# 4263  456      4        yes              affirm  None  None
# 2480  271      13       correct          affirm  None  None
# 4061  435      3        yes danish food  affirm  None  None
# 179   20       2        yes              affirm  None  None
# 3249  354      1        yes              affirm  None  None

# %%
dstc_intent_df[dstc_intent_df['intent'] == 'inform'].sample(20)
# Out:
#       dial_id  turn_id  \
# 2339  259      6
# 3306  360      4
# 697   79       0
# 2640  287      6
# 2636  287      3
# 1666  194      2
# 676   77       1
# 4614  496      1
# 1616  190      0
# 849   94       4
# 761   87       1
# 3508  377      6
# 2845  308      1
# 3465  373      1
# 2037  232      3
# 1590  187      1
# 1624  191      2
# 4142  443      0
# 604   69       4
# 4133  442      1
#
#                                                                    usr_utt  \
# 2339  curry prince address and phone number
# 3306  how about turkish food
# 697   south part of town italian food
# 2640  expensive
# 2636  korean food expensive
# 1666  i dont care
# 676   south
# 4614  any
# 1616  im looking for a restaurant that serves mexican food
# 849   american
# 761   can you find a moderately priced restaurant
# 3508  uh doesnt matter
# 2845  moderate priced restaurant that serves indian food
# 3465  i am looking for an expensive restaurant that serves australian food
# 2037  tv_noise any
# 1590  yes iam looking for a cheap restaurant in the south part of town
# 1624  that can serve kosher food
# 4142  south expensive
# 604   indian
# 4133  any
#
#       intent        slot             val
# 2339  inform  name        curry prince
# 3306  inform  food        turkish
# 697   inform  food        italian
# 2640  inform  pricerange  expensive
# 2636  inform  food        korean
# 1666  inform  this        dontcare
# 676   inform  area        south
# 4614  inform  this        dontcare
# 1616  inform  food        mexican
# 849   inform  food        north american
# 761   inform  pricerange  moderate
# 3508  inform  this        dontcare
# 2845  inform  food        indian
# 3465  inform  pricerange  expensive
# 2037  inform  this        dontcare
# 1590  inform  area        south
# 1624  inform  food        kosher
# 4142  inform  area        south
# 604   inform  food        indian
# 4133  inform  this        dontcare

# %%
dstc_intent_df[dstc_intent_df['intent'] == 'repeat']
# Out:
#       dial_id  turn_id                     usr_utt  intent  slot   val
# 35    4        4        again please                repeat  None  None
# 38    4        6        again please                repeat  None  None
# 43    4        11       again                       repeat  None  None
# 44    4        12       repeat                      repeat  None  None
# 46    4        15       repeat                      repeat  None  None
# 2582  281      0        okay let me try this again  repeat  None  None
# 4194  450      2        repeat that                 repeat  None  None

# %%
dstc_intent_df[dstc_intent_df['val'] == 'dontcare'].sample(10)
# Out:
#       dial_id  turn_id                                       usr_utt  intent  \
# 3862  414      4        no in any area                                inform
# 3033  328      1        i dont care                                   inform
# 4547  488      1        i dont care                                   inform
# 2790  303      1        i dont care                                   inform
# 3684  396      2        any                                           inform
# 1176  133      1        it doesnt matter                              inform
# 1722  199      6        i dont care about the price range             inform
# 4362  466      0        im looking for a restaurant in any area that  inform
# 4582  492      1        any                                           inform
# 4529  486      1        any                                           inform
#
#             slot       val
# 3862  area        dontcare
# 3033  this        dontcare
# 4547  this        dontcare
# 2790  this        dontcare
# 3684  this        dontcare
# 1176  this        dontcare
# 1722  pricerange  dontcare
# 4362  area        dontcare
# 4582  this        dontcare
# 4529  this        dontcare

# %%
this_intent = 'hello'
all_words = [t for u in dstc_intent_df[dstc_intent_df['intent'] == this_intent]['usr_utt'].tolist() for t in u.split()]
wc = Counter(all_words)
print("Types: {}  Tokens: {}  Type/Token: {:.2f}".format(len(wc), len(all_words), len(wc) / len(all_words)))
# Out:
# Types: 23  Tokens: 100  Type/Token: 0.23

# %%
wc.most_common(10)
# Out:
# [(u'hello', 11),
#  (u'for', 9),
#  (u'looking', 9),
#  (u'a', 9),
#  (u'im', 7),
#  (u'hi', 7),
#  (u'restaurant', 7),
#  (u'in', 5),
#  (u'the', 5),
#  (u'town', 4)]

# %%
this_intent = 'inform'
all_words = [t for u in dstc_intent_df[dstc_intent_df['intent'] == this_intent]['usr_utt'].tolist() for t in u.split()]
wc = Counter(all_words)
print("Types: {}  Tokens: {}  Type/Token: {:.2f}".format(len(wc), len(all_words), len(wc) / len(all_words)))
# Out:
# Types: 276  Tokens: 10630  Type/Token: 0.03

# %%
this_intent = 'request'
all_words = [t for u in dstc_intent_df[dstc_intent_df['intent'] == this_intent]['usr_utt'].tolist() for t in u.split()]
wc = Counter(all_words)
print("Types: {}  Tokens: {}  Type/Token: {:.2f}".format(len(wc), len(all_words), len(wc) / len(all_words)))
# Out:
# Types: 112  Tokens: 5159  Type/Token: 0.02

# %%
Counter([' '.join(t.split()[:3]) for t in dstc_intent_df[dstc_intent_df['intent'] == 'request']['usr_utt'].tolist()]).most_common(20)
# Out:
# [(u'what is the', 193),
#  (u'phone number', 127),
#  (u'address', 101),
#  (u'can i have', 79),
#  (u'whats the address', 69),
#  (u'can i get', 63),
#  (u'whats the phone', 42),
#  (u'what type of', 39),
#  (u'may i have', 37),
#  (u'price range', 29),
#  (u'and the phone', 21),
#  (u'post code', 18),
#  (u'type of food', 15),
#  (u'what is their', 15),
#  (u'could i have', 15),
#  (u'the address', 13),
#  (u'address and phone', 12),
#  (u'phone number and', 11),
#  (u'address phone number', 10),
#  (u'and the post', 10)]

# %%
def intent_counter(df, intent, n=3):
    return Counter([' '.join(t.split()[:n]) for t in df[df['intent'] == intent]['usr_utt'].tolist()])

# %%
intent_counter(dstc_intent_df, 'inform').most_common(20)
# Out:
# [(u'im looking for', 283),
#  (u'i dont care', 76),
#  (u'any', 66),
#  (u'dont care', 41),
#  (u'i need a', 33),
#  (u'moderately priced restaurant', 25),
#  (u'i want a', 24),
#  (u'how about indian', 22),
#  (u'cheap', 22),
#  (u'restaurant in the', 22),
#  (u'north', 22),
#  (u'i am looking', 21),
#  (u'i would like', 18),
#  (u'thai food', 17),
#  (u'how about chinese', 15),
#  (u'expensive', 15),
#  (u'east', 15),
#  (u'doesnt matter', 15),
#  (u'i want to', 15),
#  (u'european food', 14)]
